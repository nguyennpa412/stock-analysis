# %%
# !scrapy crawl sum_perchange
# Out:
# 000/385: >                                                                                                    |
# EXCEPT parse_stock_data_pages
# 010/385: ==>                                                                                                  |
# 020/385: =====>                                                                                               |
# 030/385: =======>                                                                                             |
# 040/385: ==========>                                                                                          |
# 050/385: ============>                                                                                        |
# 060/385: ===============>                                                                                     |
# 070/385: ==================>                                                                                  |
# ...

# %%
# !scrapy crawl select3
# Out:
# ++++++++++++++++++++++++++++TVSI-tvsi_VIC_01052019_13062021++++++++++++++++++++++++++++
# tvsi_VIC_01052019_13062021
#            Ngày Mở cửa  ... Tổng khối lượng GD     Tổng giá trị GD
# 0    11/06/2021  117.0  ...           172900.0      202504680000.0
# 1    10/06/2021  118.5  ...           292900.0      347276390000.0
# 2    09/06/2021  120.0  ...           181330.0      240124560000.0
# 3    08/06/2021  124.9  ...           269960.0      370160940000.0
# 4    07/06/2021  122.8  ...           368180.0      457005040000.0
# ..          ...    ...  ...                ...                 ...
# 527  08/05/2019  111.5  ...           348500.0       39140770000.0
# 528  07/05/2019  112.2  ...           421350.0       47285800000.0
# 529  06/05/2019  112.0  ...           290580.0  32435699999.999996
# 530  03/05/2019  113.7  ...           705500.0       79517370000.0
# 531  02/05/2019  113.8  ...           190970.0       21671710000.0
#
# [532 rows x 11 columns]
# ...

# %%
# !scrapy crawl sum_perchange
# Out:
# ++++++++++++++++++++++++++++TVSI-SUM_PERCHANGE++++++++++++++++++++++++++++
# tvsi_sum_perchange_01012021_01052021
#     Mã chứng khoán  ... % Thay đổi
# 0              CIG  ...     178.69
# 1         FUCVREIT  ...     161.12
# 2              RIC  ...     159.45
# 3              TNT  ...     157.55
# 4              TGG  ...     131.16
# ..             ...  ...        ...
# 381            TDH  ...     -42.32
# 382            SVD  ...     -44.74
# 383            TN1  ...     -45.36
# 384            KPF  ...     -49.47
# 385            YEG  ...     -52.53
#
# [386 rows x 4 columns]
# tvsi_top3_01012021_01052021
#   Mã chứng khoán  ... % Thay đổi
# 0            CIG  ...     178.69
# 1       FUCVREIT  ...     161.12
# 2            RIC  ...     159.45
#
# [3 rows x 4 columns]
# tvsi_bot3_01012021_01052021
#   Mã chứng khoán  ... % Thay đổi
# 0            YEG  ...     -52.53
# 1            KPF  ...     -49.47
# 2            TN1  ...     -45.36
#
# [3 rows x 4 columns]
# ...

# %%
# !scrapy crawl async_top3_bot3_sum_perchange
# Out:
# ++++++++++++++++++++++++++++TVSI-tvsi_TN1_01052019_13062021++++++++++++++++++++++++++++
# tvsi_TN1_01052019_13062021
#            Ngày Mở cửa  ... Tổng khối lượng GD Tổng giá trị GD
# 0    11/06/2021   55.4  ...             2080.0    1186400000.0
# 1    10/06/2021   53.2  ...             1230.0     664990000.0
# 2    09/06/2021   52.9  ...              580.0     297820000.0
# 3    08/06/2021   52.1  ...              670.0     346340000.0
# 4    07/06/2021   52.5  ...              600.0     314120000.0
# ..          ...    ...  ...                ...             ...
# 507  05/06/2019  41.15  ...                0.0       1320000.0
# 508  04/06/2019  41.15  ...                0.0             0.0
# 509  03/06/2019   38.5  ...               30.0       1230000.0
# 510  31/05/2019   36.0  ...               30.0       1160000.0
# 511  30/05/2019   36.0  ...               30.0       1080000.0
#
# [512 rows x 11 columns]
# ...

# %%
# !scrapy crawl sector
# Out:
# ++++++++++++++++++++++++++++VIETSTOCK-bds++++++++++++++++++++++++++++
# bds
#                                      Tên chứng khoán  ...              Ngành cấp 3
# 47                                        CTCP Tasco  ...  Phát triển bất động sản
# 20                                 CTCP Sông Đà 1.01  ...            Bất động sản
# 54                                    CTCP Địa ốc 11  ...  Phát triển bất động sản
# 53                                    CTCP Licogi 14  ...  Phát triển bất động sản
# 24                           CTCP Sonadezi Long Bình  ...            Bất động sản
# ..                                               ...  ...                      ...
# 38           CTCP Đầu tư Dịch vụ Tài chính Hoàng Huy  ...  Phát triển bất động sản
# 40                      CTCP Đầu tư Văn Phú - INVEST  ...  Phát triển bất động sản
# 41                CTCP Tập đoàn Đầu tư Địa ốc No Va   ...  Phát triển bất động sản
# ...

# %%
# !scrapy crawl stock
# Out:
# ++++++++++++++++++++++++++++TVSI-hnxindex++++++++++++++++++++++++++++
# hnxindex
#            Ngày  Mở cửa  ...  Tổng khối lượng GD  Tổng giá trị GD
# 0    29/04/2021  282.35  ...         121418245.0     2.397600e+12
# 1    28/04/2021  279.95  ...          96926725.0     2.003280e+12
# 2    27/04/2021  280.35  ...         102411873.0     1.716440e+12
# 3    26/04/2021  284.69  ...         141826849.0     2.633780e+12
# 4    23/04/2021  283.10  ...         138897762.0     2.389120e+12
# ..          ...     ...  ...                 ...              ...
# 498  08/05/2019  105.11  ...          34525073.0     3.957300e+11
# 499  07/05/2019  106.06  ...          50105460.0     5.611300e+11
# 500  06/05/2019  105.84  ...          44150185.0     4.895000e+11
# 501  03/05/2019  107.18  ...          28127306.0     2.995400e+11
# 502  02/05/2019  107.88  ...          31000308.0     3.858500e+11
#
# [503 rows x 11 columns]
# ...
# ++++++++++++++++++++++++++++TVSI-upcom++++++++++++++++++++++++++++
# ...
